# %%
import joblib 
import pandas as pd

# %%
model=joblib.load("Boston_Project_Model.pkl")

# %%
new_data = pd.DataFrame({
    "ID": [25],
    "indus": [7.07],
    "chas": [0],
    "nox": [0.469],
    "rm": [6.421],
    "age": [78.9],
    "dis": [4.967],
    "rad": [2],
    "tax": [242],
    "ptratio": [17.8],
    "lstat": [9.14]
})

# %%
prediction = model.predict(new_data)

print("Predicted MEDV:", prediction[0])
# Out:
# Predicted MEDV: 21.542999999999974
